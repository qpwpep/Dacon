# %% [markdown]
# ## Import

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ## Data Load & Check Data

# %%
train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')

train.head()
# Out:
#           ID  generation  school1               major type       major1_1  \
# 0  TRAIN_000           9       22  복수 전공 ( 다중전공, 이중전공 포함 )          경제통상학
# 1  TRAIN_001           9        1  복수 전공 ( 다중전공, 이중전공 포함 )           자연과학
# 2  TRAIN_002           9       27                    단일 전공            예체능
# 3  TRAIN_003           9        1  복수 전공 ( 다중전공, 이중전공 포함 )           사회과학
# 4  TRAIN_004           9       16  복수 전공 ( 다중전공, 이중전공 포함 )  IT(컴퓨터 공학 포함)
#
#         major1_2  major_data  job  class1  class2  class3  class4  \
# 0           자연과학       False  대학생       1     4.0     NaN     NaN
# 1  IT(컴퓨터 공학 포함)        True  대학생       8     NaN     NaN     NaN
# 2            NaN       False  대학생       7     NaN     NaN     NaN
# 3  IT(컴퓨터 공학 포함)       False  대학생       7     NaN     NaN     NaN
# 4  IT(컴퓨터 공학 포함)        True  대학생       8     NaN     NaN     NaN
#
#   re_registration  contest_award nationality inflow_route  \
# 0             아니요            NaN         내국인        에브리타임
# 1             아니요            NaN         내국인        지인 추천
# 2             아니요            NaN         내국인        인스타그램
# 3             아니요            NaN         내국인        에브리타임
# 4             아니요            NaN         내국인        지인 추천
#
#                                               whyBDA what_to_gain  \
# 0                 큰 규모인 만큼, 커리큘럼이나 운영 등 관리가 잘 될것 같아서      프로젝트 경험
# 1                 큰 규모인 만큼, 커리큘럼이나 운영 등 관리가 잘 될것 같아서    데이터 분석 역량
# 2  BDA 학회원만의 혜택을 누리고 싶어서(현직자 강연, 잡 페스티벌, 기업연계 공모전 등)       공모전 경험
# 3                                       혼자 공부하기 어려워서      프로젝트 경험
# 4                 큰 규모인 만큼, 커리큘럼이나 운영 등 관리가 잘 될것 같아서       공모전 경험
#
#        hope_for_group previous_class_3 previous_class_4 previous_class_5  \
# 0   네. 온라인으로 참여하고 싶어요              NaN              NaN              NaN
# 1  네. 오프라인으로 참여하고 싶어요              NaN              NaN              NaN
# 2  네. 오프라인으로 참여하고 싶어요              NaN              NaN              NaN
# 3   네. 온라인으로 참여하고 싶어요              NaN              NaN              NaN
# 4  네. 오프라인으로 참여하고 싶어요              NaN              NaN              NaN
#
#   previous_class_6 previous_class_7 previous_class_8          major_field  \
# 0              NaN              NaN              NaN           자연과학, 사회과학
# 1              NaN              NaN              NaN                 사회과학
# 2              NaN              NaN              NaN                  예체능
# 3              NaN              NaN              NaN                   법학
# 4              NaN              NaN              NaN  IT (컴퓨터 공학 포함), 인문학
#
#   desired_career_path  completed_semester project_type  time_input  \
# 0              대학원 진학                 4.0            팀         2.0
# 1                  취업                 6.0            팀         3.0
# 2              대학원 진학                 8.0           개인        10.0
# 3                  취업                 8.0            팀         2.0
# 4                  취업                 7.0            팀         2.0
#
#                          desired_job certificate_acquisition  \
# 0                      C. 데이터 사이언티스트                 컴퓨터활용능력
# 1          B. 데이터 분석가, C. 데이터 사이언티스트                      없음
# 2  B. 데이터 분석가, C. 데이터 사이언티스트, I. 마케터                    ADsP
# 3          B. 데이터 분석가, C. 데이터 사이언티스트            SQLD, 정보처리기사
# 4                         B. 데이터 분석가                    ADsP
#
#                             desired_certificate  \
# 0  ADsP, SQLD, 빅데이터 분석 기사, 태블로 관련 자격증, 구글 애널리스트
# 1                ADsP, SQLD, 빅데이터 분석 기사, 정보처리기사
# 2                      SQLD, 빅데이터 분석 기사, 정보처리기사
# 3                              ADsP, 빅데이터 분석 기사
# 4            SQLD, 정보처리기사, 태블로 관련 자격증, 구글 애널리스트
#
#                              desired_job_except_data incumbents_level  \
# 0                                      A. 금융 / 보험 직무     시니어 (10년차 ~)
# 1                      D. 소프트웨어 개발자, F. PM / 서비스 기획자      주니어 (0~3년차)
# 2   A. 금융 / 보험 직무, B. 기획 / 전략 / 경영 직무, H. 마케터 / 영업관리      주니어 (0~3년차)
# 3                                      A. 금융 / 보험 직무      주니어 (0~3년차)
# 4  A. 금융 / 보험 직무, B. 기획 / 전략 / 경영 직무, F. PM / 서비스...      주니어 (0~3년차)
#
#                         incumbents_lecture   incumbents_company_level  \
# 0           산업 트렌드 (예시: ChatGPT로 인한 직무 변화)                해외 기업 (빅테크)
# 1  커리어 패스 과정 (예시: 비전공자/전공자의 취업 준비 및 이직 과정)     국내 빅테크 IT 계열 (네카라쿠배당토)
# 2      직무 강의 (예시: 실무 진행 방식 및 직무 준비생을 위한 팁)  국내 대기업 IT 계열 (금융, 제조 ...)
# 3  커리어 패스 과정 (예시: 비전공자/전공자의 취업 준비 및 이직 과정)     국내 빅테크 IT 계열 (네카라쿠배당토)
# 4      직무 강의 (예시: 실무 진행 방식 및 직무 준비생을 위한 팁)  국내 대기업 IT 계열 (금융, 제조 ...)
#
#   incumbents_lecture_type   incumbents_lecture_scale  \
# 0              온, 오프라인 동시  100명 이상의 리스너와 10명 이상의 현직자
# 1                    오프라인  3~50명 내외의 강의 리스너와 1명의 현직자
# 2                    오프라인  3~50명 내외의 강의 리스너와 1명의 현직자
# 3              온, 오프라인 동시  3~50명 내외의 강의 리스너와 1명의 현직자
# 4              온, 오프라인 동시  3~50명 내외의 강의 리스너와 1명의 현직자
#
#                      incumbents_lecture_scale_reason interested_company  \
# 0                       다양한 사람들과 만나서 생각을 교류할 수 있기 때문   구글 딥마인드, 카카오 브레인
# 1   더 많은 사람들이 있으면 제가 예상하지 못한 질문도 할 수 있다고 생각하기 때문입니다.              제일 기획
# 2  인원이 너무 적으면 서로 부담스러울 수 있을 것 같지만 너무 많으면 너무 피상적인 ...               Lg전자
# 3                          너무 많은 인원이 강의하면 루즈해질 것 같아서                네이버
# 4                           다양한 사람들에게 기회가 있으면 좋겠습니다.                네이버
#
#                                      expected_domain contest_participation  \
# 0                                M. 전문, 과학 및 기술 서비스업                   NaN
# 1                   J. 정보통신업, O. 공공 행정, 국방 및 사회보장 행정                   NaN
# 2        C. 제조업, K. 금융 및 보험업, R. 예술, 스포츠 및 여가관련 서비스업                   NaN
# 3                              J. 정보통신업, K. 금융 및 보험업                   NaN
# 4  K. 금융 및 보험업, M. 전문, 과학 및 기술 서비스업, R. 예술, 스포츠 및...                   NaN
#
#    idea_contest                                  onedayclass_topic  completed
# 0           NaN  Python 응용, 데이터 시각화 (Matplotlib, Seaborn 등), 머신...          0
# 1           NaN                                      머신러닝 / 딥러닝 응용          0
# 2           NaN                       머신러닝 / 딥러닝 응용, SQL 응용, 웹 크롤링          0
# 3           NaN                                      머신러닝 / 딥러닝 응용          1
# 4           NaN                       머신러닝 / 딥러닝 응용, SQL 응용, 웹 크롤링          0

# %%
train.shape
# Out:
# (748, 46)

# %%
train['completed_semester'].unique()
# Out:
# array([4.00000e+00, 6.00000e+00, 8.00000e+00, 7.00000e+00, 2.00000e+00,
#        1.00000e+01, 5.00000e+00,         nan, 9.00000e+00, 3.00000e+00,
#        2.02002e+03, 2.02410e+04, 1.00000e+00, 0.00000e+00])

# %%
train['whyBDA'].unique()
# Out:
# <StringArray>
# [               '큰 규모인 만큼, 커리큘럼이나 운영 등 관리가 잘 될것 같아서',
#  'BDA 학회원만의 혜택을 누리고 싶어서(현직자 강연, 잡 페스티벌, 기업연계 공모전 등)',
#                                       '혼자 공부하기 어려워서',
#                                     '이전 기수에 매우 만족해서',
#                                      '시간적으로 부담이 없어서',
#                       '학회 가입 시 코딩 테스트, 면접 등을 보지 않아서',
#                                    '현직자의 강의를 듣고 싶어서']
# Length: 7, dtype: str

# %%
train['what_to_gain'].unique()
# Out:
# <StringArray>
# [                                                                        '프로젝트 경험',
#                                                                        '데이터 분석 역량',
#                                                                           '공모전 경험',
#                                                                          '인적 네트워크',
#                                                           '기초적인 python, sql 지식 숙지',
#                                                                          '위 항목 전체',
#                                                                        '공모전과 프로젝트',
#  '사실 한가지를 고르기 어렵습니다..ㅠㅠ 학회를 통해 위의 4가지와 협업에 계신 전문가님들에게 유익한 정보를 얻고 소중한 경험을 하고 싶습니다.',
#                                                           '분석 역량, 공모전 경험, 인적 네트워크']
# Length: 9, dtype: str

# %%
train.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 748 entries, 0 to 747
# Data columns (total 46 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               748 non-null    str
#  1   generation                       748 non-null    int64
#  2   school1                          748 non-null    int64
#  3   major type                       726 non-null    str
#  4   major1_1                         728 non-null    str
#  5   major1_2                         309 non-null    str
#  6   major_data                       748 non-null    bool
#  7   job                              748 non-null    str
#  8   class1                           748 non-null    int64
#  9   class2                           169 non-null    float64
#  10  class3                           14 non-null     float64
#  11  class4                           1 non-null      float64
#  12  re_registration                  748 non-null    str
#  13  contest_award                    0 non-null      float64
#  14  nationality                      747 non-null    str
#  15  inflow_route                     748 non-null    str
#  16  whyBDA                           748 non-null    str
#  17  what_to_gain                     748 non-null    str
#  18  hope_for_group                   748 non-null    str
#  19  previous_class_3                 146 non-null    str
#  20  previous_class_4                 146 non-null    str
#  21  previous_class_5                 146 non-null    str
#  22  previous_class_6                 146 non-null    str
#  23  previous_class_7                 146 non-null    str
#  24  previous_class_8                 146 non-null    str
#  25  major_field                      725 non-null    str
#  26  desired_career_path              748 non-null    str
#  27  completed_semester               720 non-null    float64
#  28  project_type                     748 non-null    str
#  29  time_input                       748 non-null    float64
#  30  desired_job                      748 non-null    str
#  31  certificate_acquisition          748 non-null    str
#  32  desired_certificate              748 non-null    str
#  33  desired_job_except_data          748 non-null    str
#  34  incumbents_level                 748 non-null    str
#  35  incumbents_lecture               748 non-null    str
#  36  incumbents_company_level         748 non-null    str
#  37  incumbents_lecture_type          748 non-null    str
#  38  incumbents_lecture_scale         748 non-null    str
#  39  incumbents_lecture_scale_reason  748 non-null    str
#  40  interested_company               748 non-null    str
#  41  expected_domain                  748 non-null    str
#  42  contest_participation            6 non-null      str
#  43  idea_contest                     0 non-null      float64
#  44  onedayclass_topic                748 non-null    str
#  45  completed                        748 non-null    int64
# dtypes: bool(1), float64(7), int64(4), str(34)
# memory usage: 263.8 KB

# %% [markdown]
# ## Pre-Processing

# %%
missing_ratio = train.isnull().mean()
columns_to_drop = missing_ratio[missing_ratio > 0.8].index.tolist()

train = train.drop(columns=columns_to_drop, axis=1)
test = test.drop(columns=columns_to_drop, axis=1)

train.head(2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 4
#       1 missing_ratio = train.isnull().mean()
#       2 columns_to_drop = missing_ratio[missing_ratio > 0.8].index.tolist()
# ----> 4 train = train.drop(columns=columns_to_drop, axis=1)
#       5 test = test.drop(columns=columns_to_drop, axis=1)
#       7 train.head(2)
#
# File c:\Users\kimmu\Documents\Dacon\predicting_learner_completion\.venv\Lib\site-packages\pandas\core\frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6130 def drop(
#    6131     self,
#    6132     labels: IndexLabel | ListLike = None,
#    (...)   6139     errors: IgnoreRaise = "raise",
#    6140 ) -> DataFrame | None:
#    6141     """
#    6142     Drop specified labels from rows or columns.
#    6143
#    (...)   6286             weight  1.0     0.8
#    6287     """
# -> 6288     return super().drop(
#    6289         labels=labels,
#    6290         axis=axis,
#    6291         index=index,
#    6292         columns=columns,
#    6293         level=level,
#    6294         inplace=inplace,
#    6295         errors=errors,
#    6296     )
#
# File c:\Users\kimmu\Documents\Dacon\predicting_learner_completion\.venv\Lib\site-packages\pandas\core\generic.py:4631, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4629 elif index is not None or columns is not None:
#    4630     if axis == 1:
# -> 4631         raise ValueError("Cannot specify both 'axis' and 'index'/'columns'")
#    4632     axes = {"index": index}
#    4633     if self.ndim == 2:
#
# ValueError: Cannot specify both 'axis' and 'index'/'columns'

# %%
missing_cols = train.columns[train.isnull().any()].tolist()

for col in missing_cols:
    mode_value = train[col].mode()[0]
    train[col] = train[col].fillna(mode_value)
    test[col] = test[col].fillna(mode_value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1816816765.py in <cell line: 0>()
# ----> 1 missing_cols = train.columns[train.isnull().any()].tolist()
#       2
#       3 for col in missing_cols:
#       4     mode_value = train[col].mode()[0]
#       5     train[col] = train[col].fillna(mode_value)
#
# NameError: name 'train' is not defined

# %%
train['is_major_it'] = train['major_field'].str.contains('IT', regex=True).astype(int)
test['is_major_it'] = test['major_field'].str.contains('IT', regex=True).astype(int)

# %%
object_columns = train.select_dtypes(['object', 'bool']).columns

label_encoders = {}
for col in object_columns:
    train[col] = train[col].astype(str)
    test[col] = test[col].astype(str)

    le = LabelEncoder()
    le = le.fit(train[col])
    train[col] = le.transform(train[col])

    for label in np.unique(test[col]):
        if label not in le.classes_:
            le.classes_ = np.append(le.classes_, label)

    test[col] = le.transform(test[col])
    label_encoders[col] = le

# %% [markdown]
# ## EDA

# %%
plt.figure(figsize=(20,14))
sns.heatmap(train.corr().round(2), annot = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1264000875.py in <cell line: 0>()
#       1 plt.figure(figsize=(20,14))
# ----> 2 sns.heatmap(train.corr().round(2), annot = True)
#
# NameError: name 'train' is not defined

# %% [markdown]
# ## Feature Selection

# %%
X_train = train[['class1', 're_registration', 'inflow_route', 'time_input','is_major_it']]
y_train = train['completed']

X_test = test[['class1', 're_registration', 'inflow_route', 'time_input','is_major_it']]

# %% [markdown]
# ## Modeling

# %%
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2045893643.py in <cell line: 0>()
#       1 model = RandomForestClassifier(random_state=42)
# ----> 2 model.fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# ## Inference

# %%
pred = model.predict(X_test)

# %% [markdown]
# ## Submission

# %%
submission = pd.read_csv('sample_submission.csv')
submission['completed'] = pred
submission.to_csv('submit.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3191362117.py in <cell line: 0>()
# ----> 1 submission = pd.read_csv('data/sample_submission.csv')
#       2 submission['completed'] = pred
#       3 submission.to_csv('submit.csv', index = False)
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/sample_submission.csv'
